# %% [markdown]
# # RTP Forecasting

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import keras
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.layers import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
print(tf.__version__)
# Out:
# 2.12.1

# %%
cwd = os.getcwd()

# %%
def make_dir(path):
    if os.path.exists(path) is False:
        os.makedirs(path)

# %%
#timing callback
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
# Plot history and future
def plot_predictions(pred , actual, title):
    plt.figure(figsize=(20, 4), dpi=150)
    plt.plot(np.arange(len(pred)), np.array(pred),label='cnn_lstm',alpha=0.7)
    plt.plot(np.arange(len(pred)), np.array(actual),label='PF', alpha=0.7)
    plt.axhline(y=0, color='black', linestyle='--', lw=1, alpha=0.5)
    plt.legend(loc='upper right')
    plt.xlabel('Time step' ,  fontsize=18)
    plt.ylabel('Price' , fontsize=18)
    plt.title(title, fontsize=16)

# %%
# Plot history and future
def plot_predictions_slide(pred_1,pred_2,pred_3, actual, title):
    plt.figure(figsize=(20, 4), dpi=150)
    plt.plot(np.arange(len(pred_1)), np.array(actual),label='PF', alpha=0.7)
    plt.plot(np.arange(len(pred_1)), np.array(pred_1),label='cnn_lstm-24',alpha=0.7)
    plt.plot(np.arange(len(pred_1)), np.array(pred_2),label='cnn_lstm-48',alpha=0.7)
    plt.plot(np.arange(len(pred_1)), np.array(pred_3),label='cnn_lstm-27',alpha=0.7)
    plt.axhline(y=0, color='black', linestyle='--', lw=1, alpha=0.5)
    plt.legend(loc='upper right')
    plt.xlabel('Time step' ,  fontsize=18)
    plt.ylabel('Price' , fontsize=18)
    plt.title(title, fontsize=16)

# %%
#zones = ['CAPITL', 'CENTRL', 'DUNWOD', 'GENESE', 'HUD VL', 'LONGIL',
#         'MHK VL', 'MILLWD', 'N.Y.C.', 'NORTH', 'WEST']
zone = 'N.Y.C.'
year = 2021

# %% [markdown]
# ### Data Import

# %%
# Read each timeseries (RTP = Real-Time Price, DAP = Day-Ahead Price, LF = Load Forecast)
raw_DAP = pd.read_csv("nyiso/da_lmp_zones_df_2015_2021.csv", index_col=0)
raw_RTP = pd.read_csv("nyiso/rt_lmp_zones_df_2015_2021.csv", index_col=0)
raw_LF = pd.read_csv("nyiso/load_frcstd_df_2015_2021.csv", index_col=0)

# %%
# Prepare the dataset as a dataframe
raw_data = pd.concat([raw_DAP.loc[:,zone], raw_LF.loc[:,zone], raw_RTP.loc[:,zone]],
                       axis=1).loc['2017-01-01 05:00:00+00:00':]
raw_data.columns = ['DAP', 'LF', 'RTP']
raw_data.index.names = ['date']
raw_data.to_csv('nyiso/NYISO_'+zone+'_raw.csv')

# %%
raw_data
# Out:
#                              DAP    LF    RTP
# date
# 2017-01-01 05:00:00+00:00  33.60  5065  32.28
# 2017-01-01 06:00:00+00:00  32.05  4934  30.77
# 2017-01-01 07:00:00+00:00  29.23  4812  31.17
# 2017-01-01 08:00:00+00:00  25.02  4728  32.00
# 2017-01-01 09:00:00+00:00  26.94  4665  27.89
# ...                          ...   ...    ...
# 2022-01-01 00:00:00+00:00  33.49  5362  30.21
# 2022-01-01 01:00:00+00:00  31.28  5139  30.23
# 2022-01-01 02:00:00+00:00  30.49  4943  30.34
# 2022-01-01 03:00:00+00:00  29.73  4809  30.60
# 2022-01-01 04:00:00+00:00  29.00  4720  29.93
#
# [43824 rows x 3 columns]

# %%
# We perform log tranformation before feeding the dataset into the model to make enhance the performance
# We only log tranform the price data (RTP and DAP)
log = 1
# log transformation for the forecasting task log10(Y + 1 - min(Y))
if log:
    log_data = raw_data.copy(deep=True)
    log_data.loc[:,"DAP"] = np.log(raw_data.loc[:,"DAP"] + 1 - min(raw_data.loc[:,"DAP"]))
    log_data.loc[:,"RTP"] = np.log(raw_data.loc[:,"RTP"] + 1 - min(raw_data.loc[:,"RTP"]))
    log_data.to_csv('nyiso/NYISO_'+zone+'_log.csv')

# %%
log_data
# Out:
#                                 DAP    LF       RTP
# date
# 2017-01-01 05:00:00+00:00  3.361417  5065  5.143475
# 2017-01-01 06:00:00+00:00  3.306154  4934  5.134621
# 2017-01-01 07:00:00+00:00  3.197039  4812  5.136974
# 2017-01-01 08:00:00+00:00  3.008155  4728  5.141839
# 2017-01-01 09:00:00+00:00  3.098740  4665  5.117515
# ...                             ...   ...       ...
# 2022-01-01 00:00:00+00:00  3.357594  5362  5.131318
# 2022-01-01 01:00:00+00:00  3.277522  5139  5.131436
# 2022-01-01 02:00:00+00:00  3.247269  4943  5.132086
# 2022-01-01 03:00:00+00:00  3.217275  4809  5.133620
# 2022-01-01 04:00:00+00:00  3.187592  4720  5.129662
#
# [43824 rows x 3 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Split dataset: 2015 year for training and 2016-2017 years for testing
x_train_df = log_data.iloc[:8760*4+24,:]
x_test_df = log_data.iloc[8760*4+24:,:]

y_train_df = log_data.iloc[:8760*4+24,2:]
y_test_df = log_data.iloc[8760*4+24:,2:]

# %%
# Standardization
x_mean, x_std = x_train_df.mean(), x_train_df.std()
y_mean, y_std = y_train_df.mean(), y_train_df.std()

x_train = ((x_train_df - x_mean)/x_std).to_numpy()
x_test = ((x_test_df - x_mean)/x_std).to_numpy()

y_train = ((y_train_df - y_mean)/y_std).to_numpy()
y_test = ((y_test_df - y_mean)/y_std).to_numpy()

print(x_train.shape,y_train.shape,x_test.shape, y_test.shape)
# Out:
# (35064, 3) (35064, 1) (8760, 3) (8760, 1)

# %% [markdown]
# ### Lag = 24

# %% [markdown]
# #### Reshape to (samples, steps, features)

# %%
n_steps_in = 24
n_steps_out = 24

x_train_cnn_lstm = np.array([x_train[i:i+n_steps_in] for i in range(0, x_train.shape[0]-n_steps_in-n_steps_out+1)])
y_train_cnn_lstm = np.array([y_train[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_train.shape[0]-n_steps_in-n_steps_out+1)])

x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])

print(x_train_cnn_lstm.shape,y_train_cnn_lstm.shape,x_test_cnn_lstm.shape,y_test_cnn_lstm.shape)
# Out:
# (35017, 24, 3) (35017, 24, 1) (8713, 24, 3) (8713, 24, 1)

# %% [markdown]
# #### Tuned hyperparameters

# %%
# set hyperparameters (already tuned)
n_filters   = 40 # number of filters
kernel_size = 3  # kernel size for Covolutional layers
pool_size   = 1  # size for average pooling layers
n_cnn_lstm_unit = 32 # number of cnn_lstm units
activation  = 'tanh' # activation function
learning_rate = 0.001 # learning rate
minibatch_size = 64   # batch size
num_epochs     = 50   # number of total epochs

# %% [markdown]
# #### Building the model

# %%
# define model
cnn_lstm_model = Sequential()
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(MaxPooling1D(pool_size))
cnn_lstm_model.add(LSTM(n_cnn_lstm_unit, activation=activation))
cnn_lstm_model.add(Dense(n_cnn_lstm_unit, activation='linear'))
cnn_lstm_model.add(Dense(n_steps_out, activation='linear'))
cnn_lstm_model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
cnn_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 12, 40)            400
#
#  conv1d_1 (Conv1D)           (None, 6, 40)             4840
#
#  max_pooling1d (MaxPooling1D  (None, 6, 40)            0
#  )
#
#  lstm (LSTM)                 (None, 32)                9344
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 16,432
# Trainable params: 16,432
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Running training

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = cnn_lstm_model.fit(x_train_cnn_lstm, y_train_cnn_lstm, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.2, verbose=1,
                        callbacks=[early_stop],
                        shuffle=False)
# Out:
# Epoch 1/50
# 438/438 [==============================] - 7s 13ms/step - loss: 0.8718 - val_loss: 0.2360
# Epoch 2/50
# 438/438 [==============================] - 6s 14ms/step - loss: 0.7852 - val_loss: 0.2205
# Epoch 3/50
# 438/438 [==============================] - 7s 15ms/step - loss: 0.7292 - val_loss: 0.2197
# Epoch 4/50
# 438/438 [==============================] - 6s 15ms/step - loss: 0.7199 - val_loss: 0.2169
# Epoch 5/50
# 438/438 [==============================] - 6s 14ms/step - loss: 0.7173 - val_loss: 0.2165
# Epoch 6/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7007 - val_loss: 0.2101
# Epoch 7/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6786 - val_loss: 0.2062
# Epoch 8/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6922 - val_loss: 0.2089
# Epoch 9/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6995 - val_loss: 0.2036
# Epoch 10/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6808 - val_loss: 0.2029
# Epoch 11/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6513 - val_loss: 0.2004
# Epoch 12/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6423 - val_loss: 0.2009
# Epoch 13/50
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6253 - val_loss: 0.2013
# Epoch 14/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6356 - val_loss: 0.2018
# Epoch 15/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6321 - val_loss: 0.1993
# Epoch 16/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6444 - val_loss: 0.2012
# Epoch 17/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6275 - val_loss: 0.1987
# Epoch 18/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6228 - val_loss: 0.2001
# Epoch 19/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6112 - val_loss: 0.1989
# Epoch 20/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6054 - val_loss: 0.2011
# Epoch 21/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6024 - val_loss: 0.1988
# Epoch 22/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5993 - val_loss: 0.2010
# Epoch 23/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6010 - val_loss: 0.1996
# Epoch 24/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5933 - val_loss: 0.2001
# Epoch 25/50
# 438/438 [==============================] - 7s 16ms/step - loss: 0.6102 - val_loss: 0.1981
# Epoch 26/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6089 - val_loss: 0.2049
# Epoch 27/50
# 438/438 [==============================] - 7s 15ms/step - loss: 0.6343 - val_loss: 0.1998
# Epoch 28/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5952 - val_loss: 0.2016
# Epoch 29/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5928 - val_loss: 0.2031
# Epoch 30/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5795 - val_loss: 0.2031
# Epoch 31/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5793 - val_loss: 0.2039
# Epoch 32/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5774 - val_loss: 0.2044
# Epoch 33/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5754 - val_loss: 0.2056
# Epoch 34/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5736 - val_loss: 0.2072
# Epoch 35/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5768 - val_loss: 0.2028
# Epoch 36/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5751 - val_loss: 0.2082
# Epoch 37/50
# 438/438 [==============================] - 6s 14ms/step - loss: 0.5729 - val_loss: 0.2077
# Epoch 38/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5627 - val_loss: 0.2085
# Epoch 39/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5671 - val_loss: 0.2074
# Epoch 40/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5576 - val_loss: 0.2089
# Epoch 41/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5591 - val_loss: 0.2098
# Epoch 42/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5551 - val_loss: 0.2082
# Epoch 43/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5528 - val_loss: 0.2093
# Epoch 44/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5512 - val_loss: 0.2097
# Epoch 45/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5498 - val_loss: 0.2077

# %% [markdown]
# #### Saving the model

# %%
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)
# cnn_lstm_model.save(os.path.join(model_path,'cnn_lstm_model_best_24h.h5'))

# %% [markdown]
# ### Lag = 48

# %%
n_steps_in = 48
n_steps_out = 24

x_train_cnn_lstm = np.array([x_train[i:i+n_steps_in] for i in range(0, x_train.shape[0]-n_steps_in-n_steps_out+1)])
y_train_cnn_lstm = np.array([y_train[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_train.shape[0]-n_steps_in-n_steps_out+1)])

x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])

print(x_train_cnn_lstm.shape,y_train_cnn_lstm.shape,x_test_cnn_lstm.shape,y_test_cnn_lstm.shape)

# set hyperparameters (already tuned)
n_filters   = 40 # number of filters
kernel_size = 3  # kernel size for Covolutional layers
pool_size   = 1  # size for average pooling layers
n_cnn_lstm_unit = 32 # number of cnn_lstm units
activation  = 'tanh' # activation function
learning_rate = 0.001 # learning rate
minibatch_size = 64   # batch size
num_epochs     = 50   # number of total epochs

# Building the model
cnn_lstm_model = Sequential()
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(MaxPooling1D(pool_size))
cnn_lstm_model.add(LSTM(n_cnn_lstm_unit, activation=activation))
cnn_lstm_model.add(Dense(n_cnn_lstm_unit, activation='linear'))
cnn_lstm_model.add(Dense(n_steps_out, activation='linear'))
cnn_lstm_model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
cnn_lstm_model.summary()

# Running training

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = cnn_lstm_model.fit(x_train_cnn_lstm, y_train_cnn_lstm, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.2, verbose=1,
                        callbacks=[early_stop],
                        shuffle=False)

# Saving the model
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)
# cnn_lstm_model.save(os.path.join(model_path,'cnn_lstm_model_best_48h.h5'))
# Out:
# (34993, 48, 3) (34993, 24, 1) (8689, 48, 3) (8689, 24, 1)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 24, 40)            400
#
#  conv1d_3 (Conv1D)           (None, 12, 40)            4840
#
#  max_pooling1d_1 (MaxPooling  (None, 12, 40)           0
#  1D)
#
#  lstm_1 (LSTM)               (None, 32)                9344
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 16,432
# Trainable params: 16,432
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 438/438 [==============================] - 10s 19ms/step - loss: 0.8992 - val_loss: 0.2501
# Epoch 2/50
# 438/438 [==============================] - 9s 21ms/step - loss: 0.8034 - val_loss: 0.2252
# Epoch 3/50
# 438/438 [==============================] - 9s 21ms/step - loss: 0.7602 - val_loss: 0.2234
# Epoch 4/50
# 438/438 [==============================] - 8s 18ms/step - loss: 0.7331 - val_loss: 0.2170
# Epoch 5/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.7195 - val_loss: 0.2165
# Epoch 6/50
# 438/438 [==============================] - 8s 18ms/step - loss: 0.7254 - val_loss: 0.2158
# Epoch 7/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.7061 - val_loss: 0.2087
# Epoch 8/50
# 438/438 [==============================] - 8s 18ms/step - loss: 0.6964 - val_loss: 0.2074
# Epoch 9/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.7087 - val_loss: 0.2061
# Epoch 10/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6817 - val_loss: 0.2013
# Epoch 11/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6772 - val_loss: 0.2002
# Epoch 12/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6760 - val_loss: 0.1966
# Epoch 13/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6736 - val_loss: 0.2000
# Epoch 14/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6499 - val_loss: 0.1970
# Epoch 15/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6596 - val_loss: 0.1985
# Epoch 16/50
# 438/438 [==============================] - 8s 18ms/step - loss: 0.6285 - val_loss: 0.1991
# Epoch 17/50
# 438/438 [==============================] - 9s 21ms/step - loss: 0.6221 - val_loss: 0.1997
# Epoch 18/50
# 438/438 [==============================] - 9s 21ms/step - loss: 0.6187 - val_loss: 0.2008
# Epoch 19/50
# 438/438 [==============================] - 9s 20ms/step - loss: 0.6134 - val_loss: 0.2023
# Epoch 20/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6136 - val_loss: 0.2020
# Epoch 21/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6174 - val_loss: 0.2041
# Epoch 22/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6144 - val_loss: 0.2013
# Epoch 23/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6338 - val_loss: 0.2017
# Epoch 24/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.6045 - val_loss: 0.2039
# Epoch 25/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5983 - val_loss: 0.2029
# Epoch 26/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5905 - val_loss: 0.2031
# Epoch 27/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5865 - val_loss: 0.2030
# Epoch 28/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5859 - val_loss: 0.2024
# Epoch 29/50
# 438/438 [==============================] - 8s 18ms/step - loss: 0.5811 - val_loss: 0.2016
# Epoch 30/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5806 - val_loss: 0.2023
# Epoch 31/50
# 438/438 [==============================] - 8s 17ms/step - loss: 0.5800 - val_loss: 0.2008
# Epoch 32/50
# 438/438 [==============================] - 8s 19ms/step - loss: 0.5717 - val_loss: 0.2002

# %% [markdown]
# ### Lag = 72

# %%
n_steps_in = 72
n_steps_out = 24

x_train_cnn_lstm = np.array([x_train[i:i+n_steps_in] for i in range(0, x_train.shape[0]-n_steps_in-n_steps_out+1)])
y_train_cnn_lstm = np.array([y_train[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_train.shape[0]-n_steps_in-n_steps_out+1)])

x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])

print(x_train_cnn_lstm.shape,y_train_cnn_lstm.shape,x_test_cnn_lstm.shape,y_test_cnn_lstm.shape)

# set hyperparameters (already tuned)
n_filters   = 40 # number of filters
kernel_size = 3  # kernel size for Covolutional layers
pool_size   = 1  # size for average pooling layers
n_cnn_lstm_unit = 32 # number of cnn_lstm units
activation  = 'tanh' # activation function
learning_rate = 0.001 # learning rate
minibatch_size = 32   # batch size
num_epochs     = 50   # number of total epochs

# Building the model
cnn_lstm_model = Sequential()
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(Conv1D(filters=n_filters,kernel_size=kernel_size, strides=2, padding='same',
                     input_shape=(x_train_cnn_lstm.shape[1],x_train_cnn_lstm.shape[2]), activation=activation))
cnn_lstm_model.add(MaxPooling1D(pool_size))
cnn_lstm_model.add(LSTM(n_cnn_lstm_unit, activation=activation))
cnn_lstm_model.add(Dense(n_cnn_lstm_unit, activation='linear'))
cnn_lstm_model.add(Dense(n_steps_out, activation='linear'))
cnn_lstm_model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
cnn_lstm_model.summary()

# Running training

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = cnn_lstm_model.fit(x_train_cnn_lstm, y_train_cnn_lstm, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.2, verbose=1,
                        callbacks=[early_stop],
                        shuffle=False)

# Saving the model
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)
# cnn_lstm_model.save(os.path.join(model_path,'cnn_lstm_model_best_72h.h5'))
# Out:
# (34969, 72, 3) (34969, 24, 1) (8665, 72, 3) (8665, 24, 1)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 36, 40)            400
#
#  conv1d_5 (Conv1D)           (None, 18, 40)            4840
#
#  max_pooling1d_2 (MaxPooling  (None, 18, 40)           0
#  1D)
#
#  lstm_2 (LSTM)               (None, 32)                9344
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 16,432
# Trainable params: 16,432
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 875/875 [==============================] - 22s 23ms/step - loss: 0.8503 - val_loss: 0.2272
# Epoch 2/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.7353 - val_loss: 0.2177
# Epoch 3/50
# 875/875 [==============================] - 18s 20ms/step - loss: 0.6918 - val_loss: 0.2077
# Epoch 4/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6791 - val_loss: 0.2121
# Epoch 5/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.7261 - val_loss: 0.2088
# Epoch 6/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6909 - val_loss: 0.2159
# Epoch 7/50
# 875/875 [==============================] - 19s 22ms/step - loss: 0.6746 - val_loss: 0.2037
# Epoch 8/50
# 875/875 [==============================] - 19s 22ms/step - loss: 0.6624 - val_loss: 0.2097
# Epoch 9/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6565 - val_loss: 0.2071
# Epoch 10/50
# 875/875 [==============================] - 18s 21ms/step - loss: 0.6813 - val_loss: 0.2046
# Epoch 11/50
# 875/875 [==============================] - 18s 20ms/step - loss: 0.6632 - val_loss: 0.2118
# Epoch 12/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6464 - val_loss: 0.2079
# Epoch 13/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6667 - val_loss: 0.2041
# Epoch 14/50
# 875/875 [==============================] - 20s 23ms/step - loss: 0.6478 - val_loss: 0.2107
# Epoch 15/50
# 875/875 [==============================] - 19s 21ms/step - loss: 0.6766 - val_loss: 0.2055
# Epoch 16/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6419 - val_loss: 0.2043
# Epoch 17/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6665 - val_loss: 0.2007
# Epoch 18/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6516 - val_loss: 0.2081
# Epoch 19/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6435 - val_loss: 0.2018
# Epoch 20/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6290 - val_loss: 0.2141
# Epoch 21/50
# 875/875 [==============================] - 21s 24ms/step - loss: 0.6564 - val_loss: 0.2107
# Epoch 22/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6794 - val_loss: 0.2030
# Epoch 23/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6385 - val_loss: 0.2043
# Epoch 24/50
# 875/875 [==============================] - 18s 21ms/step - loss: 0.6483 - val_loss: 0.2069
# Epoch 25/50
# 875/875 [==============================] - 19s 22ms/step - loss: 0.6478 - val_loss: 0.2033
# Epoch 26/50
# 875/875 [==============================] - 19s 21ms/step - loss: 0.6414 - val_loss: 0.2043
# Epoch 27/50
# 875/875 [==============================] - 20s 23ms/step - loss: 0.6558 - val_loss: 0.2075
# Epoch 28/50
# 875/875 [==============================] - 20s 23ms/step - loss: 0.6377 - val_loss: 0.2051
# Epoch 29/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6368 - val_loss: 0.2045
# Epoch 30/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6310 - val_loss: 0.2053
# Epoch 31/50
# 875/875 [==============================] - 18s 20ms/step - loss: 0.6276 - val_loss: 0.2057
# Epoch 32/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6075 - val_loss: 0.2006
# Epoch 33/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6195 - val_loss: 0.1989
# Epoch 34/50
# 875/875 [==============================] - 20s 23ms/step - loss: 0.6112 - val_loss: 0.2006
# Epoch 35/50
# 875/875 [==============================] - 18s 21ms/step - loss: 0.5995 - val_loss: 0.2003
# Epoch 36/50
# 875/875 [==============================] - 17s 19ms/step - loss: 0.6008 - val_loss: 0.2017
# Epoch 37/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5880 - val_loss: 0.1983
# Epoch 38/50
# 875/875 [==============================] - 17s 19ms/step - loss: 0.5881 - val_loss: 0.2022
# Epoch 39/50
# 875/875 [==============================] - 17s 19ms/step - loss: 0.5871 - val_loss: 0.2001
# Epoch 40/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5707 - val_loss: 0.2016
# Epoch 41/50
# 875/875 [==============================] - 21s 24ms/step - loss: 0.5774 - val_loss: 0.2015
# Epoch 42/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5972 - val_loss: 0.1963
# Epoch 43/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.6121 - val_loss: 0.2016
# Epoch 44/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5952 - val_loss: 0.2009
# Epoch 45/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5753 - val_loss: 0.2046
# Epoch 46/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5661 - val_loss: 0.2016
# Epoch 47/50
# 875/875 [==============================] - 18s 20ms/step - loss: 0.5689 - val_loss: 0.2033
# Epoch 48/50
# 875/875 [==============================] - 20s 23ms/step - loss: 0.5555 - val_loss: 0.2040
# Epoch 49/50
# 875/875 [==============================] - 17s 20ms/step - loss: 0.5613 - val_loss: 0.2062
# Epoch 50/50
# 875/875 [==============================] - 17s 19ms/step - loss: 0.5480 - val_loss: 0.2055

# %% [markdown]
# ### Evaluate

# %%
n_steps_in = 24
x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm_24 = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])
cnn_lstm_model = load_model(os.path.join(model_path,'cnn_lstm_model_best_24h.h5'))
y_test_pred_24 = cnn_lstm_model.predict(x_test_cnn_lstm)

n_steps_in = 48
x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm_48 = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])
cnn_lstm_model = load_model(os.path.join(model_path,'cnn_lstm_model_best_48h.h5'))
y_test_pred_48 = cnn_lstm_model.predict(x_test_cnn_lstm)

n_steps_in = 72
x_test_cnn_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_cnn_lstm_72 = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])
cnn_lstm_model = load_model(os.path.join(model_path,'cnn_lstm_model_best_72h.h5'))
y_test_pred_72 = cnn_lstm_model.predict(x_test_cnn_lstm)
# Out:
# 273/273 [==============================] - 1s 3ms/step
# 272/272 [==============================] - 1s 4ms/step
# 271/271 [==============================] - 2s 6ms/step

# %%
# Evaluation metrics
errors = y_test_pred_24 - y_test_cnn_lstm_24[:,:,0]
print('24h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_48 - y_test_cnn_lstm_48[:,:,0]
print('48h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_72 - y_test_cnn_lstm_72[:,:,0]
print('72h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

print('Hour ahead only')
# Evaluation metrics for hour ahead only
errors = y_test_pred_24[:,0] - y_test_cnn_lstm_24[:,0,0]
print('24h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_48[:,0] - y_test_cnn_lstm_48[:,0,0]
print('48h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_72[:,0] - y_test_cnn_lstm_72[:,0,0]
print('72h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
# Out:
# 24h
# MAE: 0.4538
# RMSE: 0.7064
#
# 48h
# MAE: 0.4386
# RMSE: 0.7024
#
# 72h
# MAE: 0.4596
# RMSE: 0.7135
#
# Hour ahead only
# 24h
# MAE: 0.3623
# RMSE: 0.5695
#
# 48h
# MAE: 0.3267
# RMSE: 0.5499
#
# 72h
# MAE: 0.3345
# RMSE: 0.5437

# %% [markdown]
# ### Rescale and evaluate performance

# %%
y_test_pred_rescale_24 = y_test_pred_24*y_std.values + y_mean.values
y_test_cnn_lstm_rescale_24 = y_test_cnn_lstm_24*y_std.values + y_mean.values
y_test_pred_invlog_24 = np.exp(y_test_pred_rescale_24) -1 + min(raw_data.loc[:,"RTP"])
y_test_cnn_lstm_invlog_24 = np.exp(y_test_cnn_lstm_rescale_24) -1 + min(raw_data.loc[:,"RTP"])

y_test_pred_rescale_48 = y_test_pred_48*y_std.values + y_mean.values
y_test_cnn_lstm_rescale_48 = y_test_cnn_lstm_48*y_std.values + y_mean.values
y_test_pred_invlog_48 = np.exp(y_test_pred_rescale_48) -1 + min(raw_data.loc[:,"RTP"])
y_test_cnn_lstm_invlog_48 = np.exp(y_test_cnn_lstm_rescale_48) -1 + min(raw_data.loc[:,"RTP"])

y_test_pred_rescale_72 = y_test_pred_72*y_std.values + y_mean.values
y_test_cnn_lstm_rescale_72 = y_test_cnn_lstm_72*y_std.values + y_mean.values
y_test_pred_invlog_72 = np.exp(y_test_pred_rescale_72) -1 + min(raw_data.loc[:,"RTP"])
y_test_cnn_lstm_invlog_72 = np.exp(y_test_cnn_lstm_rescale_72) -1 + min(raw_data.loc[:,"RTP"])

# %%
# Evaluation metrics
# 24 hours ahead
# Evaluation metrics
errors = y_test_pred_invlog_24 - y_test_cnn_lstm_invlog_24[:,:,0]
print('24h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_invlog_48 - y_test_cnn_lstm_invlog_48[:,:,0]
print('48h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_invlog_72 - y_test_cnn_lstm_invlog_72[:,:,0]
print('72h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

print('Hour ahead only')
# Evaluation metrics for hour ahead only
errors = y_test_pred_invlog_24[:,0] - y_test_cnn_lstm_invlog_24[:,0,0]
print('24h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_invlog_48[:,0] - y_test_cnn_lstm_invlog_48[:,0,0]
print('48h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
print('')

errors = y_test_pred_invlog_72[:,0] - y_test_cnn_lstm_invlog_72[:,0,0]
print('72h')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
# Out:
# 24h
# MAE: 11.6092
# RMSE: 21.8043
#
# 48h
# MAE: 11.1771
# RMSE: 21.7785
#
# 72h
# MAE: 11.6884
# RMSE: 21.9278
#
# Hour ahead only
# 24h
# MAE: 9.4519
# RMSE: 18.2524
#
# 48h
# MAE: 8.5225
# RMSE: 18.0336
#
# 72h
# MAE: 8.6385
# RMSE: 17.8797

# %%
i = 7*24*30
j = i + 24*30

plot_predictions_slide(y_test_pred_invlog_24[i+48:j+48,0].flatten(),
                       y_test_pred_invlog_48[i+24:j+24,0].flatten(),
                       y_test_pred_invlog_72[i:j,0].flatten(),
                       y_test_cnn_lstm_invlog_72[i:j,0,0].flatten(),
                       'RTP Predictions - NYC - 1 hour ahead - Jul-2021')

plot_predictions_slide(y_test_pred_invlog_24[i+48:j+48:24,:].flatten(),
                       y_test_pred_invlog_48[i+24:j+24:24,:].flatten(),
                       y_test_pred_invlog_72[i:j:24,:].flatten(),
                       y_test_cnn_lstm_invlog_72[i:j:24,:].flatten(),
                       'RTP Predictions - NYC - 24 hour ahead - Jul-2021')

# %%
i = 0*24*30
j = i + 24*30

plot_predictions_slide(y_test_pred_invlog_24[i+48:j+48,0].flatten(),
                       y_test_pred_invlog_48[i+24:j+24,0].flatten(),
                       y_test_pred_invlog_72[i:j,0].flatten(),
                       y_test_cnn_lstm_invlog_72[i:j,0,0].flatten(),
                       'RTP Predictions - NYC - 1 hour ahead - Jan-2021')

plot_predictions_slide(y_test_pred_invlog_24[i+48:j+48:24,:].flatten(),
                       y_test_pred_invlog_48[i+24:j+24:24,:].flatten(),
                       y_test_pred_invlog_72[i:j:24,:].flatten(),
                       y_test_cnn_lstm_invlog_72[i:j:24,:].flatten(),
                       'RTP Predictions - NYC - 24 hour ahead - Jan-2021')
