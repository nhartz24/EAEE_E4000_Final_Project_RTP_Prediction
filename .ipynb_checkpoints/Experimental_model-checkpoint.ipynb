# %% [markdown]
# # RTP Forecasting

# %%
import argparse
import os
import random
import numpy as np
import time
import datetime
import pandas as pd
import matplotlib.pyplot as plt

import sys 
import scipy.io
import math
from datetime import date       

import imageio

import tensorflow as tf
from tensorflow import keras
import keras
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Lambda, LSTM
from tensorflow.keras.layers import concatenate, Input, GlobalAveragePooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import *

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import LabelEncoder, MinMaxScaler


# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# 2023-11-23 20:20:04.735488: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
cwd = os.getcwd()

# %%
def make_dir(path):
    if os.path.exists(path) is False:
        os.makedirs(path)

# %%
#timing callback
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
# Plot history and future
def plot_predictions(pred , actual, title):
    plt.figure(figsize=(20, 4), dpi=150)
    plt.plot(np.arange(len(pred)), np.array(pred),label='LSTM',alpha=0.7)
    plt.plot(np.arange(len(pred)), np.array(actual),label='PF', alpha=0.7)
    plt.axhline(y=0, color='black', linestyle='--', lw=1, alpha=0.5)
    plt.legend(loc='upper right')
    plt.xlabel('Time step' ,  fontsize=18)
    plt.ylabel('Price' , fontsize=18)
    plt.title(title, fontsize=16)

# %%
#zones = ['CAPITL', 'CENTRL', 'DUNWOD', 'GENESE', 'HUD VL', 'LONGIL',
#         'MHK VL', 'MILLWD', 'N.Y.C.', 'NORTH', 'WEST']
zone = 'N.Y.C.'
year = 2021

# %% [markdown]
# ### Data Import

# %%
# Read each timeseries (RTP = Real-Time Price, DAP = Day-Ahead Price, LF = Load Forecast)
raw_DAP = pd.read_csv("nyiso/da_lmp_zones_df_2015_2021.csv", index_col=0)
raw_RTP = pd.read_csv("nyiso/rt_lmp_zones_df_2015_2021.csv", index_col=0)
raw_LF = pd.read_csv("nyiso/load_frcstd_df_2015_2021.csv", index_col=0)

# %%
raw_DAP
# Out:
#                            CAPITL  CENTRL  DUNWOD  GENESE  HUD VL  LONGIL  \
# 2015-01-01 05:00:00+00:00   33.45   21.89   31.27   20.84   31.14   43.73
# 2015-01-01 06:00:00+00:00   26.90   21.06   26.34   20.19   26.25   41.16
# 2015-01-01 07:00:00+00:00   25.00   19.64   24.40   18.83   24.35   37.69
# 2015-01-01 08:00:00+00:00   24.39   18.39   23.51   17.60   23.44   31.52
# 2015-01-01 09:00:00+00:00   25.00   18.39   23.99   17.57   23.92   30.00
# ...                           ...     ...     ...     ...     ...     ...
# 2022-01-01 00:00:00+00:00   33.09   29.00   33.46   28.22   33.01   39.61
# 2022-01-01 01:00:00+00:00   30.61   27.62   31.28   26.84   30.83   38.01
# 2022-01-01 02:00:00+00:00   29.49   27.55   30.41   26.89   29.99   36.29
# 2022-01-01 03:00:00+00:00   29.63   25.37   29.62   24.71   29.25   30.36
# 2022-01-01 04:00:00+00:00   28.70   24.87   28.82   24.33   28.48   29.54
#
#                            MHK VL  MILLWD  N.Y.C.  NORTH   WEST
# 2015-01-01 05:00:00+00:00   22.68   31.40   31.45  20.06  20.77
# 2015-01-01 06:00:00+00:00   21.76   26.41   26.49  20.00  19.98
# 2015-01-01 07:00:00+00:00   20.27   24.49   24.54  18.72  18.61
# 2015-01-01 08:00:00+00:00   18.97   23.59   23.64  17.35  17.45
# 2015-01-01 09:00:00+00:00   18.97   24.07   24.10  17.23  17.46
# ...                           ...     ...     ...    ...    ...
# 2022-01-01 00:00:00+00:00   30.13   33.25   33.49  28.38  27.64
# 2022-01-01 01:00:00+00:00   28.70   31.07   31.28  27.20  26.22
# 2022-01-01 02:00:00+00:00   28.55   30.24   30.49  27.28  26.20
# 2022-01-01 03:00:00+00:00   26.26   29.49   29.73  24.72  24.27
# 2022-01-01 04:00:00+00:00   25.64   28.71   29.00  24.19  24.08
#
# [61368 rows x 11 columns]

# %%
# Prepare the dataset as a dataframe
raw_data = pd.concat([raw_DAP.loc[:,zone], raw_LF.loc[:,zone], raw_RTP.loc[:,zone]],
                       axis=1).loc['2017-01-01 05:00:00+00:00':]
raw_data.columns = ['DAP', 'LF', 'RTP']
raw_data.index.names = ['date']
raw_data.to_csv('nyiso/NYISO_'+zone+'_raw.csv')

# %%
raw_data
# Out:
#                              DAP    LF    RTP
# date
# 2017-01-01 05:00:00+00:00  33.60  5065  32.28
# 2017-01-01 06:00:00+00:00  32.05  4934  30.77
# 2017-01-01 07:00:00+00:00  29.23  4812  31.17
# 2017-01-01 08:00:00+00:00  25.02  4728  32.00
# 2017-01-01 09:00:00+00:00  26.94  4665  27.89
# ...                          ...   ...    ...
# 2022-01-01 00:00:00+00:00  33.49  5362  30.21
# 2022-01-01 01:00:00+00:00  31.28  5139  30.23
# 2022-01-01 02:00:00+00:00  30.49  4943  30.34
# 2022-01-01 03:00:00+00:00  29.73  4809  30.60
# 2022-01-01 04:00:00+00:00  29.00  4720  29.93
#
# [43824 rows x 3 columns]

# %%
# We perform log tranformation before feeding the dataset into the model to make enhance the performance
# We only log tranform the price data (RTP and DAP)
log = 1
# log transformation for the forecasting task log10(Y + 1 - min(Y))
if log:
    log_data = raw_data.copy(deep=True)
    log_data.loc[:,"DAP"] = np.log(raw_data.loc[:,"DAP"] + 1 - min(raw_data.loc[:,"DAP"]))
    log_data.loc[:,"RTP"] = np.log(raw_data.loc[:,"RTP"] + 1 - min(raw_data.loc[:,"RTP"]))
    log_data.to_csv('nyiso/NYISO_'+zone+'_log.csv')

# %%
log_data
# Out:
#                                 DAP    LF       RTP
# date
# 2017-01-01 05:00:00+00:00  3.361417  5065  5.143475
# 2017-01-01 06:00:00+00:00  3.306154  4934  5.134621
# 2017-01-01 07:00:00+00:00  3.197039  4812  5.136974
# 2017-01-01 08:00:00+00:00  3.008155  4728  5.141839
# 2017-01-01 09:00:00+00:00  3.098740  4665  5.117515
# ...                             ...   ...       ...
# 2022-01-01 00:00:00+00:00  3.357594  5362  5.131318
# 2022-01-01 01:00:00+00:00  3.277522  5139  5.131436
# 2022-01-01 02:00:00+00:00  3.247269  4943  5.132086
# 2022-01-01 03:00:00+00:00  3.217275  4809  5.133620
# 2022-01-01 04:00:00+00:00  3.187592  4720  5.129662
#
# [43824 rows x 3 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Split dataset: 2015 year for training and 2016-2017 years for testing
x_train_df = log_data.iloc[:8760*4+24,:]
x_test_df = log_data.iloc[8760*4+24:,:]

y_train_df = log_data.iloc[:8760*4+24,2:]
y_test_df = log_data.iloc[8760*4+24:,2:]

# %%
# # Standardization
x_mean, x_std = x_train_df.mean(), x_train_df.std()
y_mean, y_std = y_train_df.mean(), y_train_df.std()

x_train = ((x_train_df - x_mean)/x_std).to_numpy()
x_test = ((x_test_df - x_mean)/x_std).to_numpy()

y_train = ((y_train_df - y_mean)/y_std).to_numpy()
y_test = ((y_test_df - y_mean)/y_std).to_numpy()

print(x_train.shape,y_train.shape,x_test.shape, y_test.shape)
# Out:
# (35064, 3) (35064, 1) (8760, 3) (8760, 1)

# %% [markdown]
# ### Reshape to (samples, steps, features)

# %%
n_steps_in = 24
n_steps_out = 24

x_train_lstm = np.array([x_train[i:i+n_steps_in] for i in range(0, x_train.shape[0]-n_steps_in-n_steps_out+1)])
y_train_lstm = np.array([y_train[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_train.shape[0]-n_steps_in-n_steps_out+1)])

x_test_lstm = np.array([x_test[i:i+n_steps_in] for i in range(0, x_test.shape[0]-n_steps_in-n_steps_out+1)])
y_test_lstm = np.array([y_test[i+n_steps_in:i+n_steps_in+n_steps_out] for i in range(0, y_test.shape[0]-n_steps_in-n_steps_out+1)])

print(x_train_lstm.shape,y_train_lstm.shape,x_test_lstm.shape,y_test_lstm.shape)
# Out:
# (35017, 24, 3) (35017, 24, 1) (8713, 24, 3) (8713, 24, 1)

# %%
# n_steps_in = 24
# n_steps_out = 24


# def create_lagged_features_3d(df, lag=1, lead=1):
#     if not isinstance(df, pd.DataFrame):
#         df = pd.DataFrame(df, columns=['DAP', 'LF', 'RTP'])
    
#     def _rename_lag(ser, j):
#         ser.name = ser.name + '-' + f'{j}'
#         return ser
    
#     def _rename_lead(ser, j):
#         ser.name = ser.name + '+' + f'{j}'
#         return ser
    
#     lagged_dfs = {}  # Dictionary to store lagged DataFrames for each feature
    
#     for feature in df.columns:
#         lagged_feature_df = pd.DataFrame(index=df.index)
        
#         # Fill lagged values
#         if feature == 'LF':
#             # Fill leading values
#             for i in range(1, lead + 1):
#                 lagged_feature_df[f'{feature}+{i}'] = df[feature].shift(-i)
#         else:
#             for i in range(0, lag):
#                 lagged_feature_df[f'{feature}-{i}'] = df[feature].shift(i)
        
        
#         lagged_feature_df.dropna(inplace=True)
#         lagged_dfs[feature] = lagged_feature_df
    
#     return lagged_dfs



# def create_labels(df, lead=1):
#     if not type(df) == pd.DataFrame:
#         df = pd.DataFrame(df, columns=["RTP"])
    
#     def _rename_lead(ser, j):
#         ser.name = ser.name + '+' + f'{j}'
#         return ser
        
#     for i in range(1, lead + 1):
#         df = df.join(df.RTP.shift(-i).pipe(_rename_lead, i))
#     df.dropna(inplace=True)
#     df.drop('RTP', axis=1, inplace=True)
#     return df

# # example series
# x_train_new = create_lagged_features_3d(x_train, lag=n_steps_in, lead=n_steps_out)
# y_train_new = create_labels(y_train[n_steps_out-1:], lead=n_steps_out)
# x_test_new = create_lagged_features_3d(x_test, lag=n_steps_in, lead=n_steps_out)
# y_test_new = create_labels(y_test[n_steps_out-1:], lead=n_steps_out)

# x_train_lstm_new = np.dstack((np.array(x_train_new['DAP'][:-n_steps_out]), np.array(x_train_new['LF'][n_steps_out-1:]), np.array(x_train_new['DAP'][:-n_steps_out])))
# y_train_lstm_new = np.array(y_train_new).reshape(y_train_new.shape[0],y_train_new.shape[1],1)
# x_test_lstm_new = np.dstack((np.array(x_test_new['DAP'][:-n_steps_out]), np.array(x_test_new['LF'][n_steps_out-1:]), np.array(x_test_new['DAP'][:-n_steps_out])))
# y_test_lstm_new = np.array(y_test_new).reshape(y_test_new.shape[0],y_test_new.shape[1],1)
# print(x_train_lstm_new.shape,y_train_lstm_new.shape,x_test_lstm_new.shape,y_test_lstm_new.shape)

# %%
# n_steps_in = 24
# n_steps_out = 24

# def create_lagged_features(df, lag=1, lead=1):
#     if not type(df) == pd.DataFrame:
#         df = pd.DataFrame(df, columns=['DAP', 'LF', "RTP"])
    
#     def _rename_lag(ser, j):
#         ser.name = ser.name + '-' + f'{j}'
#         return ser
#     def _rename_lead(ser, j):
#         ser.name = ser.name + '+' + f'{j}'
#         return ser
        
#     # add a column lagged by `i` steps
#     for i in range(1, lag + 1):
#         df = df.join(df.DAP.shift(i).pipe(_rename_lag, i))
#     for i in range(1, lead + 1):
#         df = df.join(df.LF.shift(-i).pipe(_rename_lead, i))
#     for i in range(1, lag + 1):
#         df = df.join(df.RTP.shift(i).pipe(_rename_lag, i))
#     df.dropna(inplace=True)
#     df.drop('LF', axis=1, inplace=True)
#     return df

# def create_labels(df, lead=1):
#     if not type(df) == pd.DataFrame:
#         df = pd.DataFrame(df, columns=["RTP"])
    
#     def _rename_lead(ser, j):
#         ser.name = ser.name + '+' + f'{j}'
#         return ser
        
#     for i in range(1, lead + 1):
#         df = df.join(df.RTP.shift(-i).pipe(_rename_lead, i))
#     df.dropna(inplace=True)
#     df.drop('RTP', axis=1, inplace=True)
#     return df

# # example series
# x_train_new = create_lagged_features(x_train, lag=n_steps_in-1, lead=n_steps_out)
# y_train_new = create_labels(y_train[n_steps_in-1:], lead=n_steps_out)
# x_test_new = create_lagged_features(x_test, lag=n_steps_in-1, lead=n_steps_out)
# y_test_new = create_labels(y_test[n_steps_in-1:], lead=n_steps_out)

# x_train_lstm_new = np.array(x_train_new).reshape(x_train_new.shape[0],1,x_train_new.shape[1])
# y_train_lstm_new = np.array(y_train_new).reshape(y_train_new.shape[0],1,y_train_new.shape[1])
# x_test_lstm_new = np.array(x_test_new).reshape(x_test_new.shape[0],1,x_test_new.shape[1])
# y_test_lstm_new = np.array(y_test_new).reshape(y_test_new.shape[0],1,y_test_new.shape[1])
# print(x_train_lstm_new.shape,y_train_lstm_new.shape,x_test_lstm_new.shape,y_test_lstm_new.shape)

# %%
print(x_train_lstm.shape,y_train_lstm.shape,x_test_lstm.shape,y_test_lstm.shape)
# Out:
# (35017, 24, 3) (35017, 24, 1) (8713, 24, 3) (8713, 24, 1)

# %%
# set hyperparameters
n_neuron       = 32
activation     = 'relu'
num_epochs     = 50
learning_rate  = 0.001
minibatch_size = 64
model_num      = 1

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(n_neuron,input_shape=(x_train_lstm.shape[1],x_train_lstm.shape[2]),
               return_sequences=True,activation=activation))
lstm_model.add(LSTM(n_neuron,return_sequences=False,
               activation=activation))
lstm_model.add(Dense(n_neuron,activation=activation))
lstm_model.add(Dense(y_train_lstm.shape[-2],activation='linear')) 

lstm_model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 24, 32)            4608
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 24)                792
#
# =================================================================
# Total params: 14,776
# Trainable params: 14,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = lstm_model.fit(x_train_lstm, y_train_lstm, 
                        batch_size = minibatch_size,
                        epochs = num_epochs,
                        validation_split=0.2, verbose=1,
                        callbacks=[early_stop],
                        shuffle=False)
# Out:
# Epoch 1/50
# 438/438 [==============================] - 6s 11ms/step - loss: 0.9617 - val_loss: 0.2988
# Epoch 2/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.8321 - val_loss: 0.2450
# Epoch 3/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.7207 - val_loss: 0.2311
# Epoch 4/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.6939 - val_loss: 0.2186
# Epoch 5/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.6713 - val_loss: 0.2092
# Epoch 6/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.6488 - val_loss: 0.2035
# Epoch 7/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6343 - val_loss: 0.2052
# Epoch 8/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.6430 - val_loss: 0.2021
# Epoch 9/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.6233 - val_loss: 0.2013
# Epoch 10/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6232 - val_loss: 0.2017
# Epoch 11/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.6169 - val_loss: 0.2012
# Epoch 12/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.6215 - val_loss: 0.2023
# Epoch 13/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6218 - val_loss: 0.2011
# Epoch 14/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6135 - val_loss: 0.2012
# Epoch 15/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6133 - val_loss: 0.2005
# Epoch 16/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6117 - val_loss: 0.2029
# Epoch 17/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6321 - val_loss: 0.2000
# Epoch 18/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6057 - val_loss: 0.2003
# Epoch 19/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6172 - val_loss: 0.2010
# Epoch 20/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6126 - val_loss: 0.1992
# Epoch 21/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5978 - val_loss: 0.2011
# Epoch 22/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5995 - val_loss: 0.2014
# Epoch 23/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6003 - val_loss: 0.1997
# Epoch 24/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5869 - val_loss: 0.2028
# Epoch 25/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6056 - val_loss: 0.2033
# Epoch 26/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5910 - val_loss: 0.2014
# Epoch 27/50
# 438/438 [==============================] - 6s 14ms/step - loss: 0.5789 - val_loss: 0.2017
# Epoch 28/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5874 - val_loss: 0.2051
# Epoch 29/50
# 438/438 [==============================] - 7s 15ms/step - loss: 0.6141 - val_loss: 0.2009
# Epoch 30/50
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5770 - val_loss: 0.2034
# Epoch 31/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5878 - val_loss: 0.2056
# Epoch 32/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5944 - val_loss: 0.2068
# Epoch 33/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5756 - val_loss: 0.2018
# Epoch 34/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5779 - val_loss: 0.2026
# Epoch 35/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5653 - val_loss: 0.2045
# Epoch 36/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5609 - val_loss: 0.2070
# Epoch 37/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5600 - val_loss: 0.2090
# Epoch 38/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5637 - val_loss: 0.2113
# Epoch 39/50
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5591 - val_loss: 0.2110
# Epoch 40/50
# 438/438 [==============================] - 5s 10ms/step - loss: 0.5640 - val_loss: 0.2087

# %%
model_path = os.path.join(cwd,'saved_model')
make_dir(model_path)

# %%
lstm_model.save(os.path.join(model_path,'LSTM_model_nov23.h5'))

# %% [markdown]
# ### Evaluate

# %%
# reload the saved model
lstm_model = load_model(os.path.join(model_path,'LSTM_model_nov23.h5'))

y_test_pred = lstm_model.predict(x_test_lstm)
# Out:
# 273/273 [==============================] - 1s 3ms/step

# %%
y_test_pred.shape
# Out:
# (8713, 24)

# %%
y_test_lstm.shape
# Out:
# (8713, 24, 1)

# %%
# Evaluation metrics
errors = y_test_pred - y_test_lstm[:,:,0]
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
# Out:
# MAE: 0.4774
# RMSE: 0.7379

# %%
# Evaluation metrics
# 24 hours ahead
errors = y_test_pred[::24,:] - y_test_lstm[::24,:,0]
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))
# Out:
# MAE: 0.4724
# RMSE: 0.7305

# %%
plot_predictions(y_test_pred[::24,:].flatten(), y_test_lstm[::24,:,0].flatten(), '')

# %% [markdown]
# ### Rescale and evaluate performance

# %%
y_test_pred_rescale = y_test_pred*y_std.values + y_mean.values
y_test_lstm_rescale = y_test_lstm*y_std.values + y_mean.values

y_test_pred_invlog = np.exp(y_test_pred_rescale) -1 + min(raw_data.loc[:,"RTP"])
y_test_lstm_invlog = np.exp(y_test_lstm_rescale) -1 + min(raw_data.loc[:,"RTP"])

# %%
# Evaluation metrics
# 24 hours ahead
errors = y_test_pred_invlog[:,0] - y_test_lstm_invlog[:,0,0]
print('Hour Ahead Evaluation')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))

errors = y_test_pred_invlog[::24,:] - y_test_lstm_invlog[::24,0,:]
print('24-Hours Ahead Evaluation')
print('MAE: {:.4f}'.format(np.abs(errors).mean()))
print('RMSE: {:.4f}'.format(np.sqrt(np.square(errors).mean())))

plot_predictions(y_test_pred_invlog[:,0].flatten(), y_test_lstm_invlog[:,0,0].flatten(), 'Hour Ahead')
plot_predictions(y_test_pred_invlog[::24,:].flatten(), y_test_lstm_invlog[::24,:,0].flatten(), '24-Hours Ahead')
# Out:
# Hour Ahead Evaluation
# MAE: 9.9158
# RMSE: 19.0320
# 24-Hours Ahead Evaluation
# MAE: 12.3211
# RMSE: 17.3483

# %%
i = 7*24*30
j = i + 24*30

plot_predictions(y_test_pred_invlog[i:j,0].flatten(),
               y_test_lstm_invlog[i:j,0,0].flatten(),
               'RTP Predictions - NYC - 1 hour ahead - Jul-2021')

plot_predictions(y_test_pred_invlog[i:j:24,:].flatten(),
               y_test_lstm_invlog[i:j:24,:].flatten(),
               'RTP Predictions - NYC - 24 hours ahead - Jul-2021')
